# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os 

### THIS IS MEANT TO RUN ON NERO - NEEDS TO BE CHANGED IF YOU RUN LOCALLY
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/home/ccorbin/.config/gcloud/application_default_credentials.json' 
os.environ['GCLOUD_PROJECT'] = 'som-nero-phi-jonc101' 
# %load_ext google.cloud.bigquery

from google.cloud import bigquery
client=bigquery.Client()
# Out:
# /share/sw/open/anaconda/3/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
query = """
SELECT DISTINCT cohort.pat_enc_csn_id_coded, cults.order_proc_id_coded, cs.sens_organism_sid, cs.line, cs.organism, cs.antibiotic, cs.suscept, cs.sensitivity_value, cs.sens_ref_range 
FROM `mining-clinical-decisions.abx.culture_orders_within_24_hrs` cults
INNER JOIN `mining-clinical-decisions.abx.interm_cohort_with_no_inf_rules` cohort
USING (pat_enc_csn_id_coded)
INNER JOIN `shc_core.culture_sensitivity` cs
USING (order_proc_id_coded)
WHERE organism <> "COAG NEGATIVE STAPHYLOCOCCUS"
ORDER BY cohort.pat_enc_csn_id_coded, cults.order_proc_id_coded, cs.line
"""
query_job =client.query(query)
df=query_job.to_dataframe()

# %%
df.head()
# Out:
#    pat_enc_csn_id_coded  order_proc_id_coded sens_organism_sid  line  \
# 0          131003775398            357750415              ZZ00     1
# 1          131003775398            357750415              ZZ00     2
# 2          131003775398            357750415              ZZ00     3
# 3          131003775398            357750415              ZZ00     4
# 4          131003775398            357750415              ZZ00     5
#
#              organism               antibiotic      suscept sensitivity_value  \
# 0  KLEBSIELLA OXYTOCA               Ampicillin    Resistant              >=32
# 1  KLEBSIELLA OXYTOCA                Cefazolin  Susceptible                 8
# 2  KLEBSIELLA OXYTOCA  Piperacillin/Tazobactam  Susceptible               <=4
# 3  KLEBSIELLA OXYTOCA               Gentamicin  Susceptible               <=1
# 4  KLEBSIELLA OXYTOCA            Ciprofloxacin  Susceptible            <=0.25
#
#   sens_ref_range
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None

# %%
df.sort_values('antibiotic').antibiotic.unique()
# Out:
# array(['5-Flucytosine', 'Amikacin', 'Amoxicillin/Clavulanic Acid',
#        'Amphotericin B', 'Ampicillin', 'Ampicillin/Sulbactam',
#        'Anidulafungin', 'Antibiotic', 'Aztreonam', 'Aztreonam.',
#        'Beta Lactamase', 'BlaZ PCR', 'Carbapenemase', 'Caspofungin',
#        'Cefazolin', 'Cefazolin..', 'Cefepime', 'Cefotaxime',
#        'Cefotaxime/Clavulanic Acid', 'Cefotetan', 'Cefoxitin',
#        'Cefpodoxime', 'Ceftaroline', 'Ceftazidime', 'Ceftazidime.',
#        'Ceftazidime/Clavulanic Acid', 'Ceftazidime/avibactam',
#        'Ceftolozane/Tazobactam', 'Ceftriaxone', 'Ceftriaxone (Meningeal)',
#        'Ceftriaxone (Non-Meningeal)', 'Ceftriaxone.', 'Cefuroxime (IV)',
#        'Cefuroxime (PO)', 'Cephalexin/Cephalothin', 'Chloramphenicol',
#        'Ciprofloxacin', 'Ciprofloxacin.', 'Clarithromycin', 'Clindamycin',
#        'Colistin', 'D-Test', 'DORIPENEM', 'Daptomycin', 'Doxycycline',
#        'ESBL confirmation test', 'Ertapenem', 'Erythromycin',
#        'Esbl Check', 'FOSFOMYCIN', 'Fluconazole', 'Gentamicin',
#        'Gentamicin 500 mcg/ml.', 'Gentamicin Synergy', 'IMP PCR',
#        'Imipenem', 'Inducible Clindamycin', 'Isavuconazole',
#        'Itraconazole', 'KPC PCR', 'Levofloxacin', 'Linezolid', 'MecA PCR',
#        'MecA PCR (Xpert)', 'Meropenem', 'Meropenem/vaborbactam', 'Method',
#        'Metronidazole', 'Micafungin', 'Minocycline', 'Moxifloxacin',
#        'NDM PCR', 'Nitrofurantoin', 'OXA48-LIKE PCR', 'Oxacillin',
#        'Oxacillin Screen', 'Oxacillin.', 'PENICILLIN G (MENINGEAL)',
#        'PENICILLIN G (NON-MENINGEAL)', 'PENICILLIN V (ORAL)',
#        'Penicillin', 'Penicillin..', 'Piperacillin',
#        'Piperacillin/Tazobactam', 'Polymixin B', 'Posaconazole',
#        'Quinupristin/Dalfopristin', 'Rifampin',
#        'Streptomycin 1000 mcg/ml', 'Streptomycin Synergy', 'Tetracycline',
#        'Ticacarcillin/Clavulanic Acid', 'Ticarcillin', 'Tigecycline',
#        'Tobramycin', 'Trimethoprim/Sulfamethoxazole',
#        'Trimethoprim/Sulfamethoxazole.', 'VIM PCR', 'Vancomycin',
#        'Voriconazole', 'ermPCR'], dtype=object)

# %% [markdown]
# ## Logic For Filling In AST
#    * If same organism name listed for two separate sens_organism_sids, assume sensitivity of one is sensitivity of other if sensitivity for one is not listed.

# %%
df_unique_orgs_per_order = (df
.groupby(['pat_enc_csn_id_coded', 'order_proc_id_coded', 'organism'])
.agg({'sens_organism_sid' : lambda x: len(set(x))})
.reset_index()
)

# %%
df_unique_orgs_per_order.groupby('sens_organism_sid').count()
# Out:
#                    pat_enc_csn_id_coded  order_proc_id_coded  organism
# sens_organism_sid
# 1                                 10591                10591     10591
# 2                                   997                  997       997
# 3                                    28                   28        28
# 4                                    12                   12        12

# %%
df['suscept'].unique()
# Out:
# array(['Resistant', 'Susceptible', 'Negative', None, 'Intermediate',
#        'Positive', 'Synergy', 'No Synergy', 'No Interpretation',
#        'Not done', 'Susceptible - Dose Dependent', 'Non Susceptible',
#        'Detected', 'Not Detected'], dtype=object)

# %%
def combine_labels(arr):
    """
    Sometimes organisms have multiple suscept labels. When they do, if any of them are not one of
    Susceptible, Positive, or Susceptible - Dose Dependent then we say organism is resistant to 
    said antibiotic
    """
    for a in arr:
        if a not in ['Susceptible', 'Positive', 'Susceptible - Dose Dependent']:
            return 'Resistant'
    return 'Susceptible'

def combine_antibiotic_syns(x):
    if x == 'Aztreonam.':
        return 'Aztreonam'
    elif x == 'Cefazolin..':
        return 'Cefazolin'
    elif x == 'Ceftazidime.':
        return 'Ceftazidime'
    elif x in ('Ceftriaxone (Meningeal)', 'Ceftriaxone (Non-Meningeal)', 'Ceftriaxone.'):
        return 'Ceftriaxone'
    elif x in ('Ciprofloxacin.'):
        return 'Ciprofloxacin'
    elif x == 'Gentamicin 500 mcg/ml.':
        return 'Gentamicin'
    elif x in ('Oxacillin Screen', 'Oxacillin.'):
        return 'Oxacillin'
    elif x in ('PENICILLIN G (MENINGEAL)','PENICILLIN G (NON-MENINGEAL)', 'PENICILLIN V (ORAL)', 'Penicillin..'):
        return 'Penicillin'
    elif x == 'Trimethoprim/Sulfamethoxazole.':
        return 'Trimethoprim/Sulfamethoxazole'
    else:
        return x

df[['pat_enc_csn_id_coded', 'order_proc_id_coded', 'sens_organism_sid', 'organism']].fillna(9999, inplace=True)
df_combined = (df
.assign(example = lambda x: x.pat_enc_csn_id_coded.map(str) + ', ' + x.order_proc_id_coded.map(str) + ', ' + x.sens_organism_sid + ', ' + x.organism,
        antibiotic = lambda x: [combine_antibiotic_syns(a) for a in x.antibiotic])
.groupby(['example', 'antibiotic'])
.agg({'suscept' : lambda x: combine_labels(x)})          
.reset_index()
)
# Out:
# /share/sw/open/anaconda/3/lib/python3.6/site-packages/pandas/core/frame.py:3790: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
df_combined.head()
# Out:
#                                              example              antibiotic  \
# 0  131003775398, 357750415, ZZ00, KLEBSIELLA OXYTOCA              Ampicillin
# 1  131003775398, 357750415, ZZ00, KLEBSIELLA OXYTOCA               Cefazolin
# 2  131003775398, 357750415, ZZ00, KLEBSIELLA OXYTOCA           Ciprofloxacin
# 3  131003775398, 357750415, ZZ00, KLEBSIELLA OXYTOCA  ESBL confirmation test
# 4  131003775398, 357750415, ZZ00, KLEBSIELLA OXYTOCA              Gentamicin
#
#        suscept
# 0    Resistant
# 1  Susceptible
# 2  Susceptible
# 3    Resistant
# 4  Susceptible

# %%
filter_cols = ['example', 'pat_enc_csn_id_coded', 'organism', 'order_proc_id_coded', 'sens_organism_sid',
               'Cefepime', 'Ceftriaxone', 'Cefazolin', 'Vancomycin', 'Meropenem', 'Piperacillin/Tazobactam',
               'Ampicillin', 'Penicillin', 'Oxacillin']

df_wide = (df_combined
.pivot(index='example', columns='antibiotic', values='suscept')
.reset_index()
.assign(organism = lambda x: [a.split(', ')[3] for a in x.example],
        order_proc_id_coded = lambda x: [a.split(', ')[1] for a in x.example],
        sens_organism_sid = lambda x: [a.split(', ')[2] for a in x.example],
        pat_enc_csn_id_coded = lambda x: [a.split(', ')[0] for a in x.example])
)[filter_cols]

# %%
df_wide.head(20)
# Out:
# antibiotic                                            example  \
# 0           131003775398, 357750415, ZZ00, KLEBSIELLA OXYTOCA
# 1           131003775398, 357750417, ZZ00, KLEBSIELLA OXYTOCA
# 2            131003775398, 357750417, ZZ01, PROTEUS MIRABILIS
# 3           131004006894, 358490468, ZZ00, STREPTOCOCCUS A...
# 4           131004006894, 358490468, ZZ01, STREPTOCOCCUS A...
# 5           131004006894, 358490468, ZZ02, STREPTOCOCCUS C...
# 6           131004006894, 358490468, ZZ03, STREPTOCOCCUS C...
# 7           131004006894, 358490468, ZZ04, STREPTOCOCCUS C...
# 8           131004006894, 358490468, ZZ05, STREPTOCOCCUS C...
# 9             131004013925, 358505019, ZZ00, ESCHERICHIA COLI
# 10            131004013925, 358505019, ZZ01, ESCHERICHIA COLI
# 11            131004041439, 358591451, ZZ00, ESCHERICHIA COLI
# 12          131004041439, 358591451, ZZ01, KLEBSIELLA PNEU...
# 13          131004041439, 358593946, ZZ00, KLEBSIELLA PNEU...
# 14          131004896326, 358746907, ZZ00, ENTEROCOCCUS SP...
# 15          131004896326, 358746907, ZZ01, ENTEROCOCCUS SP...
# 16          131006575711, 358789205, ZZ00, STREPTOCOCCUS A...
# 17            131006586590, 358794206, ZZ00, ESCHERICHIA COLI
# 18          131006601177, 358854721, ZZ00, KLEBSIELLA PNEU...
# 19          131006601177, 358854721, ZZ01, STENOTROPHOMONA...
#
# antibiotic pat_enc_csn_id_coded                            organism  \
# 0                  131003775398                  KLEBSIELLA OXYTOCA
# 1                  131003775398                  KLEBSIELLA OXYTOCA
# 2                  131003775398                   PROTEUS MIRABILIS
# 3                  131004006894       STREPTOCOCCUS ANGINOSUS GROUP
# 4                  131004006894       STREPTOCOCCUS ANGINOSUS GROUP
# 5                  131004006894          STREPTOCOCCUS CONSTELLATUS
# 6                  131004006894          STREPTOCOCCUS CONSTELLATUS
# 7                  131004006894          STREPTOCOCCUS CONSTELLATUS
# 8                  131004006894          STREPTOCOCCUS CONSTELLATUS
# 9                  131004013925                    ESCHERICHIA COLI
# 10                 131004013925                    ESCHERICHIA COLI
# 11                 131004041439                    ESCHERICHIA COLI
# 12                 131004041439               KLEBSIELLA PNEUMONIAE
# 13                 131004041439               KLEBSIELLA PNEUMONIAE
# 14                 131004896326                ENTEROCOCCUS SPECIES
# 15                 131004896326                ENTEROCOCCUS SPECIES
# 16                 131006575711  STREPTOCOCCUS AGALACTIAE {GROUP B}
# 17                 131006586590                    ESCHERICHIA COLI
# 18                 131006601177               KLEBSIELLA PNEUMONIAE
# 19                 131006601177        STENOTROPHOMONAS MALTOPHILIA
#
# antibiotic order_proc_id_coded sens_organism_sid     Cefepime  Ceftriaxone  \
# 0                    357750415              ZZ00          NaN          NaN
# 1                    357750417              ZZ00  Susceptible  Susceptible
# 2                    357750417              ZZ01  Susceptible  Susceptible
# 3                    358490468              ZZ00          NaN  Susceptible
# 4                    358490468              ZZ01          NaN  Susceptible
# 5                    358490468              ZZ02          NaN  Susceptible
# 6                    358490468              ZZ03          NaN  Susceptible
# 7                    358490468              ZZ04          NaN  Susceptible
# 8                    358490468              ZZ05          NaN  Susceptible
# 9                    358505019              ZZ00  Susceptible  Susceptible
# 10                   358505019              ZZ01          NaN          NaN
# 11                   358591451              ZZ00          NaN          NaN
# 12                   358591451              ZZ01          NaN          NaN
# 13                   358593946              ZZ00  Susceptible  Susceptible
# 14                   358746907              ZZ00          NaN          NaN
# 15                   358746907              ZZ01          NaN          NaN
# 16                   358789205              ZZ00          NaN          NaN
# 17                   358794206              ZZ00  Susceptible          NaN
# 18                   358854721              ZZ00          NaN          NaN
# 19                   358854721              ZZ01          NaN          NaN
#
# antibiotic    Cefazolin   Vancomycin    Meropenem Piperacillin/Tazobactam  \
# 0           Susceptible          NaN          NaN             Susceptible
# 1           Susceptible          NaN  Susceptible             Susceptible
# 2           Susceptible          NaN  Susceptible             Susceptible
# 3                   NaN          NaN          NaN                     NaN
# 4                   NaN          NaN          NaN                     NaN
# 5                   NaN          NaN          NaN                     NaN
# 6                   NaN          NaN          NaN                     NaN
# 7                   NaN          NaN          NaN                     NaN
# 8                   NaN          NaN          NaN                     NaN
# 9           Susceptible          NaN          NaN               Resistant
# 10                  NaN          NaN          NaN                     NaN
# 11          Susceptible          NaN          NaN             Susceptible
# 12          Susceptible          NaN          NaN             Susceptible
# 13          Susceptible          NaN  Susceptible               Resistant
# 14                  NaN  Susceptible          NaN                     NaN
# 15                  NaN  Susceptible          NaN                     NaN
# 16                  NaN          NaN          NaN                     NaN
# 17          Susceptible          NaN          NaN             Susceptible
# 18          Susceptible          NaN          NaN             Susceptible
# 19                  NaN          NaN          NaN                     NaN
#
# antibiotic   Ampicillin   Penicillin Oxacillin
# 0             Resistant          NaN       NaN
# 1             Resistant          NaN       NaN
# 2           Susceptible          NaN       NaN
# 3                   NaN          NaN       NaN
# 4                   NaN  Susceptible       NaN
# 5                   NaN          NaN       NaN
# 6                   NaN  Susceptible       NaN
# 7                   NaN          NaN       NaN
# 8                   NaN  Susceptible       NaN
# 9             Resistant          NaN       NaN
# 10                  NaN          NaN       NaN
# 11          Susceptible          NaN       NaN
# 12            Resistant          NaN       NaN
# 13            Resistant          NaN       NaN
# 14                  NaN    Resistant       NaN
# 15            Resistant    Resistant       NaN
# 16                  NaN  Susceptible       NaN
# 17            Resistant          NaN       NaN
# 18            Resistant          NaN       NaN
# 19                  NaN          NaN       NaN

# %%
## Fills in abx suscept if same organism from same patient encounter and one suscept listed but not the other
cols = ['Cefepime', 'Ceftriaxone', 'Cefazolin', 'Vancomycin', 'Meropenem', 'Piperacillin/Tazobactam', 'Ampicillin', 'Penicillin', 'Oxacillin']
df_wide[cols] = (df_wide
.groupby(['pat_enc_csn_id_coded', 'organism'])[cols]
.transform(lambda x: x.ffill().bfill())
)

# %% [markdown]
# ### Find bugs that are never listed as Susceptible or Resistant to different antibiotics

# %%
(df_wide
.rename(columns={'Piperacillin/Tazobactam' : "Zosyn"})
.groupby('organism')
.agg({'pat_enc_csn_id_coded' : 'nunique',
      'Cefazolin' : lambda x: 1 if any(x=="Susceptible") or any(x=='Resistant') else 0,
      'Ceftriaxone' : lambda x: 1 if any(x=="Susceptible") or any(x=='Resistant') else 0,
      'Cefepime' : lambda x: 1 if any(x=="Susceptible") or any(x=='Resistant') else 0,
      'Vancomycin' : lambda x: 1 if any(x=="Susceptible") or any(x=='Resistant') else 0,
      'Meropenem' : lambda x: 1 if any(x=="Susceptible") or any(x=='Resistant') else 0,
      'Zosyn' : lambda x: 1 if any(x=="Susceptible") or any(x=='Resistant') else 0,
      'Ampicillin' : lambda x: 1 if any(x=="Susceptible") or any(x=='Resistant') else 0,
      'Penicillin' : lambda x: 1 if any(x=="Susceptible") or any(x=='Resistant') else 0,
      'Oxacillin' : lambda x: 1 if any(x=="Susceptible") or any(x=='Resistant') else 0,
      })
.reset_index()
.query("Meropenem == 0")
.sort_values('pat_enc_csn_id_coded', ascending=False)
).to_csv('Mero_never_listed.csv', index=None)

# %%
len(df_wide
.query("organism.str.contains('STAPHYLOCOCCUS AUREUS') and not Cefazolin.isna()", engine='python')
)
# Out:
# 68

# %% [markdown]
# ### Read bacteria AST rules

# %%
df_bug_rules = pd.read_csv('Bacteria_AST_Rules.csv')
df_bug_rules.head()
# Out:
#                                           Organism  Num Isolated in Cohort  \
# 0  ABIOTROPHIA SPECIES (OR GRANULICATELLA SPECIES)                       1
# 1                       ACHROMOBACTER XYLOSOXIDANS                       9
# 2                          ACINETOBACTER BAUMANNII                       7
# 3                  ACINETOBACTER BAUMANNII COMPLEX                       7
# 4                             ACINETOBACTER LWOFFI                       9
#
#    cefazolin_r  cefazolin_s  Cefazolin Refer To Penicillin  ceftriaxone_r  \
# 0          NaN          NaN                            NaN            NaN
# 1          NaN          NaN                            NaN            NaN
# 2          NaN          NaN                            NaN            NaN
# 3          NaN          NaN                            NaN            NaN
# 4          NaN          NaN                            NaN            NaN
#
#    ceftriaxone_s  cefepime_r  cefepime_s  zosyn_r  zosyn_s  vancomycin_r  \
# 0            NaN         NaN         NaN      NaN      NaN           NaN
# 1            NaN         NaN         NaN      NaN      NaN           NaN
# 2            NaN         NaN         NaN      NaN      NaN           1.0
# 3            NaN         NaN         NaN      NaN      NaN           1.0
# 4            NaN         NaN         NaN      NaN      NaN           1.0
#
#    vancomycin_s  meropenem_r  meropenem_s
# 0           NaN          NaN          NaN
# 1           NaN          NaN          NaN
# 2           NaN          NaN          NaN
# 3           NaN          NaN          NaN
# 4           NaN          NaN          NaN

# %%
import pdb
def fill_in_cefazolin(x):
    
    # If not missing just return what it is. 
    if x.Cefazolin == 'Susceptible' or x.Cefazolin == 'Resistant':
        return x.Cefazolin
    
    # Read in bug rules
    df_bug_rules = pd.read_csv('Bacteria_AST_Rules.csv')
    r_bugs = set(df_bug_rules.query("cefazolin_r == 1")['Organism'].values)
    s_bugs = set(df_bug_rules.query("cefazolin_s == 1")['Organism'].values)
    
    # Uses hand labelled list of resistant bugs
    if x.organism in r_bugs:
        return "Resistant"
    
    # Uses hand labelled always susceptible bugs
    if x.organism in s_bugs:
        return "Susceptible"

    # For anything STREPTOCOCCUS related except STREPTOCOCCUS PNEUMONIAE  - refer to penicillin 
    if ('STREPTOCOCCUS' in x.organism or 'STREPTOCOCCI' in x.organism) and x.organism != 'STREPTOCOCCUS PNEUMONIAE':
        if x.Penicillin is not None:
            return x.Penicillin
    
    # Check For MRSA in STAPH AUREUS 
    if x.organism == 'STAPHYLOCOCCUS AUREUS':
        if x.Oxacillin is not None:
            return x.Oxacillin 
        
    # If anything resistant to Cefepime or Ceftriaxone, assume resistant to Cefazolin
    if x.Cefepime == "Resistant" or x.Ceftriaxone == 'Resistant':
        return "Resistant"
    
    # Will apply Nancy Watz Rule Later (assume susc if not listed)
    return "Not Filled In"

def fill_in_ceftriaxone(x):
    
    # If not missing just return what it is. 
    if x.Ceftriaxone == 'Susceptible' or x.Ceftriaxone == 'Resistant':
        return x.Ceftriaxone
    
    # Read in bug rules
    df_bug_rules = pd.read_csv('Bacteria_AST_Rules.csv')
    r_bugs = set(df_bug_rules.query("ceftriaxone_r == 1")['Organism'].values)
    s_bugs = set(df_bug_rules.query("ceftriaxone_s == 1")['Organism'].values)
    
    # Uses hand labelled list of resistant bugs
    if x.organism in r_bugs:
        return "Resistant"
    
    # Uses hand labelled always susceptible bugs
    if x.organism in s_bugs:
        return "Susceptible"

    # For anything STREPTOCOCCUS related - refer to penicillin 
    if ('STREPTOCOCCUS' in x.organism or 'STREPTOCOCCI' in x.organism):
        if x.Penicillin is not None:
            return x.Penicillin
        
    # Check For MRSA in STAPH AUREUS 
    if x.organism == 'STAPHYLOCOCCUS AUREUS':
        if x.Oxacillin is not None:
            return x.Oxacillin 

    # If anything resistant to Cefepime, assume resistant to Ceftriaxone
    if x.Cefepime == "Resistant":
        return "Resistant"
    
    # If susceptible to Cefazolin, assume susceptible to Ceftriaxone
    if x.Cefazolin == "Susceptible":
        return "Resistant"
    
    # Will apply Nancy Watz Rule Later (assume susc if not listed)
    return "Not Filled In"

def fill_in_cefepime(x):
    
    # If not missing just return what it is. 
    if x.Cefepime == 'Susceptible' or x.Cefepime == 'Resistant':
        return x.Cefepime
    
    # Read in bug rules
    df_bug_rules = pd.read_csv('Bacteria_AST_Rules.csv')
    r_bugs = set(df_bug_rules.query("cefepime_r == 1")['Organism'].values)
    s_bugs = set(df_bug_rules.query("cefepime_s == 1")['Organism'].values)
    
    # Uses hand labelled list of resistant bugs
    if x.organism in r_bugs:
        return "Resistant"
    
    # Uses hand labelled always susceptible bugs
    if x.organism in s_bugs:
        return "Susceptible"

    # For anything STREPTOCOCCUS related - refer to penicillin 
    if ('STREPTOCOCCUS' in x.organism or 'STREPTOCOCCI' in x.organism):
        if x.Penicillin is not None:
            return x.Penicillin
        
    # Check For MRSA in STAPH AUREUS 
    if x.organism == 'STAPHYLOCOCCUS AUREUS':
        if x.Oxacillin is not None:
            return x.Oxacillin 
    
    # If susceptible to Cefazolin or Ceftriaxone assume susceptible to Cefepime
    if x.Cefazolin == "Susceptible" or x.Ceftriaxone == "Susceptible":
        return "Susceptible"
    
    # Will apply Nancy Watz Rule Later (assume susc if not listed)
    return "Not Filled In"

def fill_in_zosyn(x):
     
    # If not missing just return what it is. 
    if x.Zosyn == 'Susceptible' or x.Zosyn == 'Resistant':
        return x.Zosyn
    
    # Read in bug rules
    df_bug_rules = pd.read_csv('Bacteria_AST_Rules.csv')
    r_bugs = set(df_bug_rules.query("zosyn_r == 1")['Organism'].values)
    s_bugs = set(df_bug_rules.query("zosyn_s == 1")['Organism'].values)
    
    # Uses hand labelled list of resistant bugs
    if x.organism in r_bugs:
        return "Resistant"
    
    # Uses hand labelled always susceptible bugs
    if x.organism in s_bugs:
        return "Susceptible"
    
    # For anything STREPTOCOCCUS related - refer to penicillin 
    if ('STREPTOCOCCUS' in x.organism or 'STREPTOCOCCI' in x.organism):
        if x.Penicillin is not None:
            return x.Penicillin
        
    # Check For MRSA in STAPH AUREUS 
    if x.organism == 'STAPHYLOCOCCUS AUREUS':
        if x.Oxacillin is not None:
            return x.Oxacillin 
        
    # If susceptible to ampicillin, then zosyn susceptible
    if x.Ampicillin == "Susceptible":
        return x.Ampicillin
    
    # Will apply Nancy Watz Rule Later (assume susc if not listed)
    return "Not Filled In"


def fill_in_vancomycin(x):
    # If not missing just return what it is. 
    if x.Vancomycin == 'Susceptible' or x.Vancomycin == 'Resistant':
        return x.Vancomycin
    
    # Read in bug rules
    df_bug_rules = pd.read_csv('Bacteria_AST_Rules.csv')
    r_bugs = set(df_bug_rules.query("vancomycin_r == 1")['Organism'].values) # Want to make sure I catch all gram negative bugs in here
    s_bugs = set(df_bug_rules.query("vancomycin_s == 1")['Organism'].values)
    
    # Uses hand labelled list of resistant bugs
    if x.organism in r_bugs:
        return "Resistant"
    
    # Uses hand labelled always susceptible bugs
    if x.organism in s_bugs:
        return "Susceptible"
    
    
    # Will apply Nancy Watz Rule Later (assume susc if not listed)
    return "Not Filled In"

def fill_in_meropenem(x):
    # If not missing just return what it is. 
    if x.Meropenem == 'Susceptible' or x.Meropenem == 'Resistant':
        return x.Meropenem
    
    # Read in bug rules
    df_bug_rules = pd.read_csv('Bacteria_AST_Rules.csv')
    r_bugs = set(df_bug_rules.query("meropenem_r == 1")['Organism'].values) # Want to make sure I catch all gram negative bugs in here
    s_bugs = set(df_bug_rules.query("meropenem_s == 1")['Organism'].values)
    
    # Uses hand labelled list of resistant bugs
    if x.organism in r_bugs:
        return "Resistant"
    
    # Uses hand labelled always susceptible bugs
    if x.organism in s_bugs:
        return "Susceptible"
    
     # Check For MRSA in STAPH AUREUS 
    if x.organism == 'STAPHYLOCOCCUS AUREUS':
        if x.Oxacillin is not None:
            return x.Oxacillin 
        
    # If susceptible to ampicillin, then meropenem susceptible
    if x.Ampicillin == "Susceptible": # not the case with Enteroccocus, but this should be in alwasys resistant list above. 
        return x.Ampicillin
    
    # Will apply Nancy Watz Rule Later (assume susc if not listed)
    return "Not Filled In"

df_wide_temp = (df_wide
.rename(columns={'Piperacillin/Tazobactam' : "Zosyn"})
.assign(Cefazolin=lambda x: df_wide.apply(lambda x: fill_in_cefazolin(x), axis=1),
        Ceftriaxone=lambda x: df_wide.apply(lambda x: fill_in_ceftriaxone(x), axis=1),
        Cefepime=lambda x: df_wide.apply(lambda x: fill_in_cefepime(x), axis=1),
        Zosyn=lambda x: df_wide.apply(lambda x: fill_in_zosyn(x), axis=1),
        Vancomycin=lambda x: df_wide.apply(lambda x: fill_in_vancomycin(x), axis=1),
        Meropenem=lambda x: df_wide.apply(lambda x: fill_in_meropenem(x), axis=1))
)

# %%
df_wide_temp.head(20)

# %%
def fill_ceftriaxone(x):
    if x.Cefazolin == "Susceptible":
        return "Susceptible"
    elif: x.organism == "PSEUDOMONAS AERUGINOSA":
        return "Resistant"
    else:
        return x.Ceftriaxone

(df_wide
.assign(Ceftriaxone = df_wide.apply(lambda x: fill_ceftriaxone(x), axis=1)) #['Susceptible' if cef == 'Susceptible' or ceft == 'Susceptible' else "Resistant" for cef, ceft in zip(x.Cefazolin, x.Ceftriaxone)])
.assign(Cefepime = lambda x: ['Susceptible' if ceft == 'Susceptible' or cef ==  "Susceptible" else "Resistant" for ceft, cef in zip(x.Ceftriaxone, x.Cefepime)])
# .assign(Ceftriaxone = lambda x: )
).head(12)
# Out:
# antibiotic                                            example  \
# 0           131003775398, 357750415, ZZ00, KLEBSIELLA OXYTOCA
# 1           131003775398, 357750417, ZZ00, KLEBSIELLA OXYTOCA
# 2            131003775398, 357750417, ZZ01, PROTEUS MIRABILIS
# 3           131004006894, 358490468, ZZ00, STREPTOCOCCUS A...
# 4           131004006894, 358490468, ZZ01, STREPTOCOCCUS A...
# 5           131004006894, 358490468, ZZ02, STREPTOCOCCUS C...
# 6           131004006894, 358490468, ZZ03, STREPTOCOCCUS C...
# 7           131004006894, 358490468, ZZ04, STREPTOCOCCUS C...
# 8           131004006894, 358490468, ZZ05, STREPTOCOCCUS C...
# 9             131004013925, 358505019, ZZ00, ESCHERICHIA COLI
# 10            131004013925, 358505019, ZZ01, ESCHERICHIA COLI
# 11            131004041439, 358591451, ZZ00, ESCHERICHIA COLI
#
# antibiotic pat_enc_csn_id_coded                       organism  \
# 0                  131003775398             KLEBSIELLA OXYTOCA
# 1                  131003775398             KLEBSIELLA OXYTOCA
# 2                  131003775398              PROTEUS MIRABILIS
# 3                  131004006894  STREPTOCOCCUS ANGINOSUS GROUP
# 4                  131004006894  STREPTOCOCCUS ANGINOSUS GROUP
# 5                  131004006894     STREPTOCOCCUS CONSTELLATUS
# 6                  131004006894     STREPTOCOCCUS CONSTELLATUS
# 7                  131004006894     STREPTOCOCCUS CONSTELLATUS
# 8                  131004006894     STREPTOCOCCUS CONSTELLATUS
# 9                  131004013925               ESCHERICHIA COLI
# 10                 131004013925               ESCHERICHIA COLI
# 11                 131004041439               ESCHERICHIA COLI
#
# antibiotic order_proc_id_coded sens_organism_sid     Cefepime  Ceftriaxone  \
# 0                    357750415              ZZ00  Susceptible  Susceptible
# 1                    357750417              ZZ00  Susceptible  Susceptible
# 2                    357750417              ZZ01  Susceptible  Susceptible
# 3                    358490468              ZZ00  Susceptible  Susceptible
# 4                    358490468              ZZ01  Susceptible  Susceptible
# 5                    358490468              ZZ02  Susceptible  Susceptible
# 6                    358490468              ZZ03  Susceptible  Susceptible
# 7                    358490468              ZZ04  Susceptible  Susceptible
# 8                    358490468              ZZ05  Susceptible  Susceptible
# 9                    358505019              ZZ00  Susceptible  Susceptible
# 10                   358505019              ZZ01  Susceptible  Susceptible
# 11                   358591451              ZZ00  Susceptible  Susceptible
#
# antibiotic    Cefazolin Vancomycin    Meropenem Piperacillin/Tazobactam  \
# 0           Susceptible        NaN  Susceptible             Susceptible
# 1           Susceptible        NaN  Susceptible             Susceptible
# 2           Susceptible        NaN  Susceptible             Susceptible
# 3                   NaN        NaN          NaN                     NaN
# 4                   NaN        NaN          NaN                     NaN
# 5                   NaN        NaN          NaN                     NaN
# 6                   NaN        NaN          NaN                     NaN
# 7                   NaN        NaN          NaN                     NaN
# 8                   NaN        NaN          NaN                     NaN
# 9           Susceptible        NaN          NaN               Resistant
# 10          Susceptible        NaN          NaN               Resistant
# 11          Susceptible        NaN          NaN             Susceptible
#
# antibiotic   Ampicillin   Penicillin Oxacillin
# 0             Resistant          NaN       NaN
# 1             Resistant          NaN       NaN
# 2           Susceptible          NaN       NaN
# 3                   NaN  Susceptible       NaN
# 4                   NaN  Susceptible       NaN
# 5                   NaN  Susceptible       NaN
# 6                   NaN  Susceptible       NaN
# 7                   NaN  Susceptible       NaN
# 8                   NaN  Susceptible       NaN
# 9             Resistant          NaN       NaN
# 10            Resistant          NaN       NaN
# 11          Susceptible          NaN       NaN

# %%
df_wide[cols].isna().sum()
# Out:
# antibiotic
# Cefepime                    7777
# Ceftriaxone                 5227
# Cefazolin                   5302
# Vancomycin                  9658
# Meropenem                   6089
# Piperacillin/Tazobactam     5131
# Ampicillin                  3548
# Penicillin                  9745
# Oxacillin                  11728
# dtype: int64

# %%
df_wide.groupby('organism').agg({'pat_enc_csn_id_coded' : 'nunique'}).sort_values('pat_enc_csn_id_coded', ascending=False).to_csv('organisms.csv')

# %% [markdown]
# ### Fill In Rules

# %%
# If same CSN, order_proc_id-

# %%
len(df[df[['example', 'antibiotic', 'suscept']].duplicated()])
# Out:
# 84

# %%
df.pivot(index='example',
         columns='antibiotic',
         values='suscept').head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-cd3952e711c3> in <module>
#       1 df.pivot(index='example',
#       2          columns='antibiotic',
# ----> 3          values='suscept').head()
#
# /share/sw/open/anaconda/3/lib/python3.6/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5192         """
#    5193         from pandas.core.reshape.reshape import pivot
# -> 5194         return pivot(self, index=index, columns=columns, values=values)
#    5195
#    5196     _shared_docs['pivot_table'] = """
#
# /share/sw/open/anaconda/3/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in pivot(self, index, columns, values)
#     413             indexed = self._constructor_sliced(self[values].values,
#     414                                                index=index)
# --> 415     return indexed.unstack(columns)
#     416
#     417
#
# /share/sw/open/anaconda/3/lib/python3.6/site-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    2897         """
#    2898         from pandas.core.reshape.reshape import unstack
# -> 2899         return unstack(self, level, fill_value)
#    2900
#    2901     # ----------------------------------------------------------------------
#
# /share/sw/open/anaconda/3/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     499         unstacker = _Unstacker(obj.values, obj.index, level=level,
#     500                                fill_value=fill_value,
# --> 501                                constructor=obj._constructor_expanddim)
#     502         return unstacker.get_result()
#     503
#
# /share/sw/open/anaconda/3/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#     135
#     136         self._make_sorted_values_labels()
# --> 137         self._make_selectors()
#     138
#     139     def _make_sorted_values_labels(self):
#
# /share/sw/open/anaconda/3/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     173
#     174         if mask.sum() < len(self.index):
# --> 175             raise ValueError('Index contains duplicate entries, '
#     176                              'cannot reshape')
#     177
#
# ValueError: Index contains duplicate entries, cannot reshape
