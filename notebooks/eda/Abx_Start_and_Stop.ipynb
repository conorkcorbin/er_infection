# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os 

### THIS IS MEANT TO RUN ON NERO - NEEDS TO BE CHANGED IF YOU RUN LOCALLY
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/home/ccorbin/.config/gcloud/application_default_credentials.json' 
os.environ['GCLOUD_PROJECT'] = 'mining-clinical-decisions' 
# %load_ext google.cloud.bigquery

from google.cloud import bigquery
client=bigquery.Client()
# Out:
# /share/sw/open/anaconda/3/lib/python3.6/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
# %%bigquery
# # Of our 60k encounters, how many didn't have any abx started
# WITH start_stop_time as (
# SELECT anon_id, pat_enc_csn_id_coded, max(was_given) any_abx_given, min(order_start_time_utc) first_abx_order_time, max(abx_stop_time) last_abx_stop_time
# FROM `mining-clinical-decisions.conor_db.abx_temp_14_day_orders`
# GROUP BY anon_id, pat_enc_csn_id_coded
# ORDER BY anon_id, pat_enc_csn_id_coded)
#
# SELECT any_abx_given, COUNT (DISTINCT pat_enc_csn_id_coded) cnt
# FROM start_stop_time
# GROUP BY any_abx_given
# Out:
#    any_abx_given    cnt
# 0              1  58691
# 1              0   2045

# %%
# %%bigquery
# # How many CSNS have abx that are stopped within given number of days. Shows distribution.  Weird how long the tail is, should investigate further.
# # Also note how 1/3 of the CSN's have abx stop within the first day. Note that these will include people sent home with PO abx who were probably
# # taking them for the full week. May end up wanting to remove PO abx from this analysis bc we can't get a stop time for them.
# WITH start_stop_time as (
# SELECT anon_id, pat_enc_csn_id_coded, max(was_given) any_abx_given, min(order_start_time_utc) first_abx_order_time, max(abx_stop_time) last_abx_stop_time
# FROM `mining-clinical-decisions.conor_db.abx_temp_14_day_orders`
# GROUP BY anon_id, pat_enc_csn_id_coded
# ORDER BY anon_id, pat_enc_csn_id_coded),
#
# er_admits AS (
# SELECT anon_id, pat_enc_csn_id_coded, min(effective_time_jittered_utc) as er_admit_time, max(effective_time_jittered_utc) as er_transfer_out_time
# FROM `shc_core.adt`
# WHERE pat_class_c = "112" AND pat_service = "Emergency"
# GROUP BY anon_id, pat_enc_csn_id_coded)
#
# SELECT
# TIMESTAMP_DIFF(ss.last_abx_stop_time, ea.er_admit_time, DAY) time_until_abx_stop, COUNT (DISTINCT ss.pat_enc_csn_id_coded) cnt
# FROM start_stop_time ss
# INNER JOIN er_admits ea
# USING (pat_enc_csn_id_coded)
# GROUP BY time_until_abx_stop
# ORDER BY time_until_abx_stop
# Out:
#      time_until_abx_stop    cnt
# 0                    NaN      2
# 1                    0.0  22375
# 2                    1.0   5182
# 3                    2.0   4678
# 4                    3.0   4233
# 5                    4.0   3101
# 6                    5.0   2168
# 7                    6.0   1789
# 8                    7.0   1342
# 9                    8.0   1096
# 10                   9.0    938
# 11                  10.0    854
# 12                  11.0    754
# 13                  12.0    692
# 14                  13.0    698
# 15                  14.0    756
# 16                  15.0    618
# 17                  16.0    567
# 18                  17.0    511
# 19                  18.0    418
# 20                  19.0    336
# 21                  20.0    289
# 22                  21.0    271
# 23                  22.0    258
# 24                  23.0    219
# 25                  24.0    231
# 26                  25.0    173
# 27                  26.0    152
# 28                  27.0    167
# 29                  28.0    145
# ..                   ...    ...
# 495               1200.0      1
# 496               1236.0      1
# 497               1238.0      1
# 498               1269.0      1
# 499               1274.0      1
# 500               1306.0      1
# 501               1319.0      1
# 502               1341.0      1
# 503               1354.0      1
# 504               1383.0      1
# 505               1410.0      1
# 506               1424.0      1
# 507               1530.0      1
# 508               1593.0      1
# 509               1605.0      1
# 510               1628.0      1
# 511               1644.0      1
# 512               1669.0      1
# 513               1693.0      1
# 514               1775.0      1
# 515               1836.0      1
# 516               1863.0      1
# 517               1865.0      1
# 518               1877.0      1
# 519               1936.0      1
# 520               2191.0      1
# 521               2285.0      1
# 522               2363.0      1
# 523               2547.0      1
# 524               2660.0      1
#
# [525 rows x 2 columns]

# %%
# %%bigquery
# # Counts the number of CSNS that that have any growth in the union of all cultures ordered within 4 hrs of er stay
# WITH cult_result as (
# SELECT DISTINCT co.anon_id, co.pat_enc_csn_id_coded, co.order_proc_id_coded, cs.organism
# FROM `mining-clinical-decisions.conor_db.abx_culture_orders_within_4_hours` co
# INNER JOIN
#   (SELECT DISTINCT pat_enc_csn_id_coded FROM `mining-clinical-decisions.conor_db.abx_med_orders_given_and_stopped_info`) cults_and_abx_csns
# USING (pat_enc_csn_id_coded)
# LEFT JOIN `shc_core.culture_sensitivity` cs
# USING (order_proc_id_coded)
# ORDER BY co.anon_id, co.pat_enc_csn_id_coded
# )
#
# SELECT any_growth, COUNT (DISTINCT pat_enc_csn_id_coded) num_csns
# FROM
#   (SELECT pat_enc_csn_id_coded, MAX(CASE WHEN organism IS NOT NULL THEN 1 ELSE 0 END) any_growth
#   FROM cult_result
#   GROUP BY pat_enc_csn_id_coded) t
# GROUP BY any_growth
# Out:
#    any_growth  num_csns
# 0           1     18633
# 1           0     42103

# %%
# %%bigquery
# # Of all encs with positive cultures, how many different kinds of bugs grew?
# WITH cult_result as (
# SELECT DISTINCT co.anon_id, co.pat_enc_csn_id_coded, co.order_proc_id_coded, cs.organism
# FROM `mining-clinical-decisions.conor_db.abx_culture_orders_within_4_hours` co
# INNER JOIN
#   (SELECT DISTINCT pat_enc_csn_id_coded FROM `mining-clinical-decisions.conor_db.abx_med_orders_given_and_stopped_info`) cults_and_abx_csns
# USING (pat_enc_csn_id_coded)
# LEFT JOIN `shc_core.culture_sensitivity` cs
# USING (order_proc_id_coded)
# ORDER BY co.anon_id, co.pat_enc_csn_id_coded
# ),
#
# any_growth as
# (SELECT pat_enc_csn_id_coded, MAX(CASE WHEN organism IS NOT NULL THEN 1 ELSE 0 END) any_positive
# FROM cult_result
# GROUP BY pat_enc_csn_id_coded)
#
# SELECT num_bugs, COUNT (DISTINCT pat_enc_csn_id_coded) num_csns
# FROM
#   (SELECT cr.pat_enc_csn_id_coded, COUNT (DISTINCT cr.organism) num_bugs
#   FROM cult_result cr
#   INNER JOIN (SELECT DISTINCT pat_enc_csn_id_coded FROM any_growth WHERE any_positive = 1) pos_csns
#   USING (pat_enc_csn_id_coded)
#   GROUP BY cr.pat_enc_csn_id_coded) t
# GROUP BY num_bugs
# ORDER BY num_bugs
# Out:
#    num_bugs  num_csns
# 0         1     16135
# 1         2      2193
# 2         3       250
# 3         4        42
# 4         5         7
# 5         6         5
# 6         7         1

# %%
# %%bigquery
# # Kinds of bugs that grow and how often stratified by department (Pediatric ER, Adult ER, Valley Care ER).  Scary thing here is most of these are pediatric.  Which I was going to exclude
# # from the cohort... Note the Pediatric and adult ER's are the same building I believe.
# WITH cult_result as (
# SELECT DISTINCT co.anon_id, co.pat_enc_csn_id_coded, co.order_proc_id_coded, cs.organism
# FROM `mining-clinical-decisions.conor_db.abx_culture_orders_within_4_hours` co
# INNER JOIN
#   (SELECT DISTINCT pat_enc_csn_id_coded FROM `mining-clinical-decisions.conor_db.abx_med_orders_given_and_stopped_info`) cults_and_abx_csns
# USING (pat_enc_csn_id_coded)
# LEFT JOIN `shc_core.culture_sensitivity` cs
# USING (order_proc_id_coded)
# ORDER BY co.anon_id, co.pat_enc_csn_id_coded
# ),
#
# any_growth as
# (SELECT pat_enc_csn_id_coded, MAX(CASE WHEN organism IS NOT NULL THEN 1 ELSE 0 END) any_positive
# FROM cult_result
# GROUP BY pat_enc_csn_id_coded),
#
# dep_id as (
# SELECT
# adt.pat_enc_csn_id_coded,
# FIRST_VALUE(adt.department_id) OVER (PARTITION BY adt.pat_enc_csn_id_coded ORDER BY adt.effective_time_jittered_utc) department_id
# FROM cult_result
# INNER JOIN `shc_core.adt` adt
# USING (pat_enc_csn_id_coded)
# )
#
# SELECT department_name, organism, COUNT (DISTINCT pat_enc_csn_id_coded) num_csns
# FROM
#   (SELECT DISTINCT cr.pat_enc_csn_id_coded, cr.organism, dm.department_name
#   FROM cult_result cr
#   INNER JOIN (SELECT DISTINCT pat_enc_csn_id_coded FROM any_growth WHERE any_positive = 1) pos_csns
#   USING (pat_enc_csn_id_coded)
#   INNER JOIN dep_id
#   USING (pat_enc_csn_id_coded)
#   INNER JOIN `shc_core.dep_map` dm
#   USING (department_id)
#   WHERE cr.organism IS NOT NULL) t
# GROUP BY department_name, organism
# ORDER BY department_name, num_csns DESC
# Out:
#                 department_name  \
# 0    ADULT EMERGENCY DEPARTMENT
# 1    ADULT EMERGENCY DEPARTMENT
# 2    ADULT EMERGENCY DEPARTMENT
# 3    ADULT EMERGENCY DEPARTMENT
# 4    ADULT EMERGENCY DEPARTMENT
# 5    ADULT EMERGENCY DEPARTMENT
# 6    ADULT EMERGENCY DEPARTMENT
# 7    ADULT EMERGENCY DEPARTMENT
# 8    ADULT EMERGENCY DEPARTMENT
# 9    ADULT EMERGENCY DEPARTMENT
# 10   ADULT EMERGENCY DEPARTMENT
# 11   ADULT EMERGENCY DEPARTMENT
# 12   ADULT EMERGENCY DEPARTMENT
# 13   ADULT EMERGENCY DEPARTMENT
# 14   ADULT EMERGENCY DEPARTMENT
# 15   ADULT EMERGENCY DEPARTMENT
# 16   ADULT EMERGENCY DEPARTMENT
# 17   ADULT EMERGENCY DEPARTMENT
# 18   ADULT EMERGENCY DEPARTMENT
# 19   ADULT EMERGENCY DEPARTMENT
# 20   ADULT EMERGENCY DEPARTMENT
# 21   ADULT EMERGENCY DEPARTMENT
# 22   ADULT EMERGENCY DEPARTMENT
# 23   ADULT EMERGENCY DEPARTMENT
# 24   ADULT EMERGENCY DEPARTMENT
# 25   ADULT EMERGENCY DEPARTMENT
# 26   ADULT EMERGENCY DEPARTMENT
# 27   ADULT EMERGENCY DEPARTMENT
# 28   ADULT EMERGENCY DEPARTMENT
# 29   ADULT EMERGENCY DEPARTMENT
# ..                          ...
# 321    VCP EMERGENCY DEPARTMENT
# 322    VCP EMERGENCY DEPARTMENT
# 323    VCP EMERGENCY DEPARTMENT
# 324    VCP EMERGENCY DEPARTMENT
# 325    VCP EMERGENCY DEPARTMENT
# 326    VCP EMERGENCY DEPARTMENT
# 327    VCP EMERGENCY DEPARTMENT
# 328    VCP EMERGENCY DEPARTMENT
# 329    VCP EMERGENCY DEPARTMENT
# 330    VCP EMERGENCY DEPARTMENT
# 331    VCP EMERGENCY DEPARTMENT
# 332    VCP EMERGENCY DEPARTMENT
# 333    VCP EMERGENCY DEPARTMENT
# 334    VCP EMERGENCY DEPARTMENT
# 335    VCP EMERGENCY DEPARTMENT
# 336    VCP EMERGENCY DEPARTMENT
# 337    VCP EMERGENCY DEPARTMENT
# 338    VCP EMERGENCY DEPARTMENT
# 339    VCP EMERGENCY DEPARTMENT
# 340    VCP EMERGENCY DEPARTMENT
# 341    VCP EMERGENCY DEPARTMENT
# 342    VCP EMERGENCY DEPARTMENT
# 343    VCP EMERGENCY DEPARTMENT
# 344    VCP EMERGENCY DEPARTMENT
# 345    VCP EMERGENCY DEPARTMENT
# 346    VCP EMERGENCY DEPARTMENT
# 347    VCP EMERGENCY DEPARTMENT
# 348    VCP EMERGENCY DEPARTMENT
# 349    VCP EMERGENCY DEPARTMENT
# 350    VCP EMERGENCY DEPARTMENT
#
#                                               organism  num_csns
# 0                                     ESCHERICHIA COLI       227
# 1                                KLEBSIELLA PNEUMONIAE        59
# 2                                 ENTEROCOCCUS SPECIES        35
# 3                                    PROTEUS MIRABILIS        32
# 4                                STAPHYLOCOCCUS AUREUS        23
# 5                               PSEUDOMONAS AERUGINOSA        22
# 6                                ENTEROCOCCUS FAECALIS        13
# 7                   STREPTOCOCCUS AGALACTIAE (GROUP B)         9
# 8                         ENTEROBACTER CLOACAE COMPLEX         8
# 9                                   KLEBSIELLA OXYTOCA         7
# 10                                KLEBSIELLA AEROGENES         7
# 11                              HAEMOPHILUS INFLUENZAE         6
# 12                        COAG NEGATIVE STAPHYLOCOCCUS         6
# 13                                  CITROBACTER KOSERI         5
# 14                                 STAPH AUREUS {MRSA}         5
# 15                            STREPTOCOCCUS PNEUMONIAE         5
# 16                        CITROBACTER FREUNDII COMPLEX         5
# 17                                 MORGANELLA MORGANII         5
# 18                                ENTEROCOCCUS FAECIUM         4
# 19                    STREPTOCOCCUS PYOGENES (GROUP A)         4
# 20                       STREPTOCOCCUS ANGINOSUS GROUP         4
# 21                          STREPTOCOCCUS DYSGALACTIAE         3
# 22                            CORYNEBACTERIUM STRIATUM         2
# 23                                PROVIDENCIA RETTGERI         2
# 24                                 SALMONELLA ENTERICA         2
# 25                      STREPTOCOCCUS SALIVARIUS GROUP         2
# 26                          ENTEROCOCCUS CASSELIFLAVUS         2
# 27                     ACINETOBACTER BAUMANNII COMPLEX         2
# 28                                    CANDIDA ALBICANS         2
# 29                       MUCOID PSEUDOMONAS AERUGINOSA         2
# ..                                                 ...       ...
# 321                        ZZZCITROBACTER AMALONATICUS         2
# 322                         BETA STREPTOCOCCUS GROUP G         2
# 323                         ENTEROCOCCUS CASSELIFLAVUS         2
# 324                               ALCALIGENES FAECALIS         2
# 325                              ACINETOBACTER SPECIES         2
# 326  STAPHYLOCOCCUS SPECIES - COAG NEGATIVE, NOT ST...         2
# 327                               CLOSTRIDIUM SEPTICUM         1
# 328                                   SERRATIA SPECIES         1
# 329                                 ENTEROCOCCUS AVIUM         1
# 330                      PSEUDOMONAS FLUORESCENS GROUP         1
# 331                                  AEROMONAS SPECIES         1
# 332              LACTOSE FERMENTING GRAM NEGATIVE RODS         1
# 333                         ACHROMOBACTER XYLOSOXIDANS         1
# 334                               ACINETOBACTER LWOFFI         1
# 335                              SERRATIA LIQUEFACIENS         1
# 336                               ENTEROCOCCUS SPECIES         1
# 337                                      CANDIDA KEFYR         1
# 338                               ENTEROBACTER SPECIES         1
# 339                                       HAFNIA ALVEI         1
# 340          NON LACTOSE FERMENTING GRAM NEGATIVE RODS         1
# 341                             STREPTOCOCCUS GORDONII         1
# 342                              ACHROMOBACTER SPECIES         1
# 343                            ENTEROCOCCUS RAFFINOSUS         1
# 344                              RAOULTELLA PLANTICOLA         1
# 345                                   CANDIDA GLABRATA         1
# 346                            STREPTOCOCCUS SANGUINIS         1
# 347       KLEBSIELLA PNEUMONIAE (CARBAPENEM RESISTANT)         1
# 348                                  SERRATIA RUBIDAEA         1
# 349                                       SPHINGOMONAS         1
# 350                                    PANTOEA SPECIES         1
#
# [351 rows x 3 columns]

# %%
# %%bigquery
# # Counts of infected, not infected, and censored patients.  Roughly half of patients are censored according to first round logic.
# SELECT sum(not_infected), sum(infected), sum(not_censored)
# FROM `mining-clinical-decisions.conor_db.abx_cohort_not_censored_label`
# Out:
#      f0_    f1_    f2_
# 0  15388  18203  33591

# %%
# %%bigquery
# # Counts of infected, not infected, and censored patients when kids removed -- still roughly half censored. more infected than uninfected
# SELECT sum(not_infected), sum(infected), sum(not_censored)
# FROM `mining-clinical-decisions.conor_db.abx_cohort_not_censored_no_kids`
# Out:
#     f0_    f1_    f2_
# 0  9931  15740  25671

# %%
# %%bigquery
# # Counts of infected, not infected, and censored patients when kids removed -- still roughly half censored. more infected than uninfected
# SELECT sum(not_infected), sum(infected), sum(not_censored)
# FROM `mining-clinical-decisions.conor_db.abx_cohort_not_censored_no_kids_no_prior`
# Out:
#     f0_   f1_    f2_
# 0  4855  8708  13563

# %%
# %%bigquery
# # get dep_names for the Ed for cohort without kids, lot of pediatric even though we're 18+.
# WITH adt_dep as (
# SELECT pat_enc_csn_id_coded, FIRST_VALUE(department_id) OVER (PARTITION BY pat_enc_csn_id_coded ORDER BY effective_time_jittered_utc) department_id
# FROM `shc_core.adt`)
#
# SELECT DISTINCT cens.*,  dep.department_name,
# FROM `mining-clinical-decisions.conor_db.abx_cohort_not_censored_no_kids` cens
# INNER JOIN adt_dep
# USING (pat_enc_csn_id_coded)
# INNER JOIN `shc_core.dep_map` dep
# USING (department_id)
# Out:
# UsageError: Cell magic `%%bigquery` not found.
